# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
indice_gini = pd.read_excel("gini_excel.xls")
indice_gini = indice_gini.drop(columns=['Indicator Code', 'Indicator Name'])
indice_gini = indice_gini.set_index(['Country Name', 'Country Code'])

indice_gini.head()
# Out:
#                            1960  1961  1962  1963  1964  1965  1966  1967  \
# Country Name Country Code
# Aruba        ABW            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan  AFG            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola       AGO            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania      ALB            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra      AND            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                            1968  1969  ...   2009  2010  2011  2012  2013  \
# Country Name Country Code              ...
# Aruba        ABW            NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN
# Afghanistan  AFG            NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN
# Angola       AGO            NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN
# Albania      ALB            NaN   NaN  ...    NaN   NaN   NaN  29.0   NaN
# Andorra      AND            NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
test = indice_gini.pivot_table(index = indice_gini.columns,
                              columns = ['Gini'],
                              values = indice_gini.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-dab62e89d401> in <module>
#       1 test = indice_gini.pivot_table(index = indice_gini.columns,
#       2                               columns = ['Gini'],
# ----> 3                               values = indice_gini.values)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5301                            aggfunc=aggfunc, fill_value=fill_value,
#    5302                            margins=margins, dropna=dropna,
# -> 5303                            margins_name=margins_name)
#    5304
#    5305     def stack(self, level=-1, dropna=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
# ...

# %%
indice_gini.values
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
